# %%
# Exercise 3

user_input = input("Enter the password to exit: ")
while True:
    pwd = input("Type 'DONORPOGI' to exit:")
    if pwd== "DONORPOGI":
        print("TAMA KA BOI.")
        break # Break terminates 
    else:
        print("MALI KA BOI.")
# Out:
# MALI KA BOI.
# MALI KA BOI.
# TAMA KA BOI.

# %%
# Exercise 2
# A= ASCII Value of first letter (Calculated in Task 5)
A = 5
# B= Seed Number (Calculated in Task 3)
B = 7
# C = Total Loop Cycles (Calculated in Task14)s1ng
C = 7

# Formula: (ASCII * Seed)- Loops 
verification_hash =(A * B) - C

print(f"Forensic Signature: {verification_hash}")
# Out:
# Forensic Signature: 28

# %%
target_name = "DONOR"   
SEED_NUM = 4            
redacted_name = ""

for char in target_name:
    if char in "AEIOU":
        redacted_name += str(SEED_NUM)
    else:
        redacted_name += char

print("Original Surname:", target_name)
print("SEED_NUM Used:", SEED_NUM)
print("Redacted Output:", redacted_name)
# Out:
# Original Surname: DONOR
# SEED_NUM Used: 4
# Redacted Output: D4N4R
